# %%
import numpy as np 
import random

train_data = np.array([[1.0,1.0]])
train_targets = np.array([1.0])

test_data = np.array([[2.0,2.0]])
test_targets = np.array([4.0])

for i in range(1,10000):
    n1 = random.randint(1, 100)
    n2 = random.randint(1, 100)
    train_data= np.append(train_data,[[n1,n2]],axis=0)
    train_targets= np.append(train_targets,[n1*n2])
    
    test_data = np.append(test_data,[[n1,n2]],axis=0)
    test_targets = np.append(test_targets,[n1*n2])

for i in range(1,2500):
    n1 = random.randint(1, 50)
    n2 = random.randint(1, 50)
    train_data= np.append(train_data,[[n1,n2]],axis=0)
    train_targets= np.append(train_targets,[n1*n2])
    
    test_data = np.append(test_data,[[n1,n2]],axis=0)
    test_targets = np.append(test_targets,[n1*n2])

for i in range(1,2500):
    n1 = random.randint(50, 100)
    n2 = random.randint(50, 100)
    train_data= np.append(train_data,[[n1,n2]],axis=0)
    train_targets= np.append(train_targets,[n1*n2])
    
    test_data = np.append(test_data,[[n1,n2]],axis=0)
    test_targets = np.append(test_targets,[n1*n2])

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(2,)),
    keras.layers.Dense(20, activation=tf.nn.relu),
	keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse',metrics=['mae'])
model.fit(train_data, train_targets, epochs=15, batch_size=1)
test_loss, test_accuracy = model.evaluate(test_data, test_targets)

print('Test accuracy:', test_accuracy)
print('Test results:')
a= np.array([[10,10],[4,5] ,[7,8],[7,20],[30,20],[50,20]])
print(model.predict(a))
# Out:
# Epoch 1/15
# 14998/14998 [==============================] - 12s 782us/step - loss: 994812.1875 - mae: 717.5074
# Epoch 2/15
# 14998/14998 [==============================] - 11s 753us/step - loss: 298577.6250 - mae: 419.0614
# Epoch 3/15
# 14998/14998 [==============================] - 11s 758us/step - loss: 151337.1875 - mae: 297.5836
# Epoch 4/15
# 14998/14998 [==============================] - 11s 727us/step - loss: 73369.9766 - mae: 207.9702
# Epoch 5/15
# 14998/14998 [==============================] - 11s 753us/step - loss: 32176.7832 - mae: 135.2988
# Epoch 6/15
# 14998/14998 [==============================] - 11s 742us/step - loss: 13838.8154 - mae: 87.2870
# Epoch 7/15
# 14998/14998 [==============================] - 11s 755us/step - loss: 8852.5283 - mae: 69.2478
# Epoch 8/15
# 14998/14998 [==============================] - 12s 775us/step - loss: 7113.9209 - mae: 60.81300s - loss: 7072.8765 - mae
# Epoch 9/15
# 14998/14998 [==============================] - 12s 772us/step - loss: 5909.5205 - mae: 54.5562
# Epoch 10/15
# 14998/14998 [==============================] - 11s 754us/step - loss: 4590.1973 - mae: 47.9859
# Epoch 11/15
# 14998/14998 [==============================] - 11s 746us/step - loss: 4391.9800 - mae: 45.43420s - loss: 4387.4409 - mae: 4
# Epoch 12/15
# 14998/14998 [==============================] - 12s 778us/step - loss: 4713.5918 - mae: 45.7305
# Epoch 13/15
# 14998/14998 [==============================] - 12s 796us/step - loss: 3780.3130 - mae: 42.0080
# Epoch 14/15
# 14998/14998 [==============================] - 12s 796us/step - loss: 3888.2444 - mae: 41.4482
# Epoch 15/15
# 14998/14998 [==============================] - 12s 771us/step - loss: 3877.1045 - mae: 40.9837
# 469/469 [==============================] - 0s 697us/step - loss: 1603.1582 - mae: 30.5288
# Test accuracy: 30.528762817382812
# Test results:
# [[114.93682 ]
#  [-29.5342  ]
#  [ 31.909113]
#  [148.93756 ]
#  [576.5614  ]
#  [992.5865  ]]
